# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.DataFrame({'value': ['100', '78','129'], 'Date': ['02/20/2015', '01/15/2016','08/21/2015']})
sorted_df = df.sort_values(by='Date')

sorted_df
# Out:
#   value        Date
# 1    78  01/15/2016
# 0   100  02/20/2015
# 2   129  08/21/2015

# %%
df = pd.read_csv('datasets/AirPassengers.csv')

# %%
df = pd.read_csv('datasets/AirPassengers.csv')
df['Month'] = pd.to_datetime(df['Month'])
plt.plot(df['Month'], df['#Passengers'])
plt.show()
# Out:
#        Month  #Passengers
# 0 1949-01-01          112
# 1 1949-02-01          118
# 2 1949-03-01          132
# 3 1949-04-01          129
# 4 1949-05-01          121

# %% [markdown]
# # Decompose the Trend and Seasonality

# %%
df = df.set_index(['Month'])

# %%
import statsmodels.api as sm

decomposition = sm.tsa.seasonal_decompose(df, model='additive')

# %%
decomposition.plot()

# %%
#

# %%
data = pd.read_csv('datasets/AAPL.csv')
data['Date'] = pd.to_datetime(data['Date'])
data['Tick'] = range(0, len(data))
plt.plot(data['Date'], data['Close'])

sampled_data = data.sample(frac=0.5).sort_values(by=['Tick'])
plt.plot(sampled_data['Date'], sampled_data['Close'])




plt.show()

# %%
sorted_df = data.sample(frac=0.5).sort_values(by=['Tick'])

sorted_df.set_index(['Tick'])

sorted_df = sorted_df.set_index(['Tick'])
sorted_df.plot()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# Tick
# 2    2014-10-13  101.330002  101.779999   95.180000   97.669998   91.683792
# 3    2014-10-20   98.320000  105.489998   98.220001  105.220001   98.771042
# 5    2014-11-03  108.220001  110.300003  107.720001  109.010002  102.328766
# 8    2014-11-24  116.849998  119.750000  116.620003  118.930000  112.124863
# 10   2014-12-08  114.099998  114.849998  109.349998  109.730003  103.451294
# 11   2014-12-15  110.699997  113.239998  106.260002  111.779999  105.383980
# 12   2014-12-22  112.160004  114.519997  111.970001  113.989998  107.467529
# 13   2014-12-29  113.790001  114.769997  107.349998  109.330002  103.074181
# 15   2015-01-12  112.599998  112.800003  105.199997  105.989998   99.925285
# 17   2015-01-26  113.739998  120.000000  109.029999  117.160004  110.456146
# 18   2015-02-02  118.050003  120.510002  116.080002  118.930000  112.124863
# ...

# %%
df = pd.read_pickle('datasets/apple_quandl.pkl')
df.head(1)
# Out:
#              Open   High    Low  Close     Volume  Ex-Dividend  Split Ratio  \
# Date
# 1980-12-12  28.75  28.87  28.75  28.75  2093900.0          0.0          1.0
#
#             Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume
# Date
# 1980-12-12   0.422706    0.42447  0.422706    0.422706  117258400.0

# %%
start = df.index.searchsorted(dt.datetime(2017, 3, 1))
end = df.index.searchsorted(dt.datetime(2017, 4, 1))

march_df = df.loc['2017-3', ["Open", "Close"]]
march_df['price'] = np.log(march_df.Close)
x = np.diff(march_df.price)
x.sum()*100

x = x.cumsum()

plt.plot([x for x in range(len(x))], x)

# %%
march_df.Close.pct_change().sum() * 100
# Out:
# 2.784543213973867
